# %%
#Multiple Regression Model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Salary_Data_1.csv")
data.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Age              30 non-null     float64
#  2   Salary           30 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
data.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
len(data)
# Out:
# 30

# %%
import pandas as pd
X=data[['YearsExperience','Age']]
X.values
# Out:
# array([[ 1.1, 21. ],
#        [ 1.3, 21.5],
#        [ 1.5, 21.7],
#        [ 2. , 22. ],
#        [ 2.2, 22.2],
#        [ 2.9, 23. ],
#        [ 3. , 23. ],
#        [ 3.2, 23.3],
#        [ 3.2, 23.3],
#        [ 3.7, 23.6],
#        [ 3.9, 23.9],
#        [ 4. , 24. ],
#        [ 4. , 24. ],
#        [ 4.1, 24. ],
#        [ 4.5, 25. ],
#        [ 4.9, 25. ],
#        [ 5.1, 26. ],
#        [ 5.3, 27. ],
#        [ 5.9, 28. ],
#        [ 6. , 29. ],
#        [ 6.8, 30. ],
#        [ 7.1, 30. ],
#        [ 7.9, 31. ],
#        [ 8.2, 32. ],
#        [ 8.7, 33. ],
#        [ 9. , 34. ],
#        [ 9.5, 35. ],
#        [ 9.6, 36. ],
#        [10.3, 37. ],
#        [10.5, 38. ]])

# %%
y = data['Salary'].values
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
y.shape
# Out:
# (30,)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8,random_state=200)

# %%
#### Build the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
### Perform Training 
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
### Perform Training 
model.fit(X,y)
# Out:
# LinearRegression()

# %%
### Prediction
ypred = model.predict(xtest)
ypred
# Out:
# array([107460.63513437, 127716.73904828,  42409.53774881,  98865.92530469,
#         38662.98691225,  81051.17791902])

# %%
model.predict([[11,39]])  #person with 11 years experience and 39 as age
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([132629.42929326])

# %%
### R2 Score
from sklearn.metrics import r2_score
r2 = r2_score(ytest,ypred)
r2*100
# Out:
# 98.97718138444172
